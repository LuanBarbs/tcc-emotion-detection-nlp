# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import wilcoxon

# %%
def load_results(path):
    df = pd.read_csv(path)

    df = df.loc[:, ~df.columns.str.contains("^Unnamed")]

    for col in df.columns:
        if col.endswith("_all"):
            df[col] = (
                df[col]
                .str.replace('[', '')
                .str.replace(']', '')
                .apply(lambda x: [float(v) for v in x.split()])
            )
    return df

def to_long_balanced(df, balanced, metric="F1_macro"):
    rows = []

    for _, row in df.iterrows():
        model = row["Model"]
        scores = row[f"CV_{metric}_all"]

        for s in scores:
            rows.append({
                "Balanced": balanced,
                "Model": model,
                metric: s
            })

    return pd.DataFrame(rows)

# %% [markdown]
# ## PlayStoreReviews

# %% [markdown]
# ### Balanced BoW

# %%
paths = {
    "BASE_TEXT": "../../data/out/baseline/baseline_08_PlayStoreReviews_BoW.csv",
    "TEXT_LEMMA": "../../data/out/preprocess/preprocess_08_PlayStoreReviews_BoW_TEXT_NO_STOP.csv",
    "TEXT_LEMMA_SMOTE": "../../data/out/balanced/balanced_08_PlayStoreReviews_BoW.csv",
}

dfs = []

for name, path in paths.items():
    df = load_results(path)
    dfs.append(to_long_balanced(df, name))

df_long = pd.concat(dfs, ignore_index=True)

df_pair = (
    df_long
    .groupby("Balanced")
    .head(df_long.groupby("Balanced").size().min())
    .reset_index(drop=True)
)

baseline = "BASE_TEXT"
balances = df_pair["Balanced"].unique()
balances = [p for p in balances if p != baseline]

results = []

scores_base = (
    df_pair[df_pair["Balanced"] == baseline]["F1_macro"]
    .to_numpy()
)

n = len(scores_base)
mean_w = n * (n + 1) / 4
std_w = np.sqrt(n * (n + 1) * (2*n + 1) / 24)

for prep in balances:
    scores_other = (
        df_pair[df_pair["Balanced"] == prep]["F1_macro"]
        .to_numpy()
    )

    stat, p = wilcoxon(scores_base, scores_other)

    z = (stat - mean_w) / std_w
    r = abs(z) / np.sqrt(n)

    results.append({
        "Comparison": f"{baseline} vs {prep}",
        "Wilcoxon_stat": stat,
        "p_value": p,
        "Z": z,
        "Effect_size_r": r
    })

df_wilcoxon = pd.DataFrame(results)
df_wilcoxon.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_f8695">
#   <thead>
#     <tr>
#       <th id="T_f8695_level0_col0" class="col_heading level0 col0" >Comparison</th>
#       <th id="T_f8695_level0_col1" class="col_heading level0 col1" >Wilcoxon_stat</th>
#       <th id="T_f8695_level0_col2" class="col_heading level0 col2" >p_value</th>
#       <th id="T_f8695_level0_col3" class="col_heading level0 col3" >Z</th>
#       <th id="T_f8695_level0_col4" class="col_heading level0 col4" >Effect_size_r</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f8695_row0_col0" class="data row0 col0" >BASE_TEXT vs TEXT_LEMMA</td>
#       <td id="T_f8695_row0_col1" class="data row0 col1" >4703.000000</td>
#       <td id="T_f8695_row0_col2" class="data row0 col2" >0.071821</td>
#       <td id="T_f8695_row0_col3" class="data row0 col3" >-1.800252</td>
#       <td id="T_f8695_row0_col4" class="data row0 col4" >0.146990</td>
#     </tr>
#     <tr>
# ...

# %%
plt.figure(figsize=(7, 4))

sns.boxplot(
    data=df_long,
    x="Balanced",
    y="F1_macro"
)

sns.stripplot(
    data=df_long,
    x="Balanced",
    y="F1_macro",
    color="black",
    alpha=0.4,
    size=3
)

plt.title("Distribution of F1-macro across text preprocessing (BoW)")
plt.ylabel("F1-macro")
plt.xlabel("")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Balanced TFIDF

# %%
paths = {
    "BASE_TEXT": "../../data/out/baseline/baseline_08_PlayStoreReviews_TFIDF.csv",
    "TEXT_LEMMA": "../../data/out/preprocess/preprocess_08_PlayStoreReviews_TFIDF_TEXT_NO_STOP.csv",
    "TEXT_LEMMA_SMOTE": "../../data/out/balanced/balanced_08_PlayStoreReviews_TFIDF.csv",
}

dfs = []

for name, path in paths.items():
    df = load_results(path)
    dfs.append(to_long_balanced(df, name))

df_long = pd.concat(dfs, ignore_index=True)

df_pair = (
    df_long
    .groupby("Balanced")
    .head(df_long.groupby("Balanced").size().min())
    .reset_index(drop=True)
)

baseline = "BASE_TEXT"
balances = df_pair["Balanced"].unique()
balances = [p for p in balances if p != baseline]

results = []

scores_base = (
    df_pair[df_pair["Balanced"] == baseline]["F1_macro"]
    .to_numpy()
)

n = len(scores_base)
mean_w = n * (n + 1) / 4
std_w = np.sqrt(n * (n + 1) * (2*n + 1) / 24)

for prep in balances:
    scores_other = (
        df_pair[df_pair["Balanced"] == prep]["F1_macro"]
        .to_numpy()
    )

    stat, p = wilcoxon(scores_base, scores_other)

    z = (stat - mean_w) / std_w
    r = abs(z) / np.sqrt(n)

    results.append({
        "Comparison": f"{baseline} vs {prep}",
        "Wilcoxon_stat": stat,
        "p_value": p,
        "Z": z,
        "Effect_size_r": r
    })

df_wilcoxon = pd.DataFrame(results)
df_wilcoxon.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_f3ccd">
#   <thead>
#     <tr>
#       <th id="T_f3ccd_level0_col0" class="col_heading level0 col0" >Comparison</th>
#       <th id="T_f3ccd_level0_col1" class="col_heading level0 col1" >Wilcoxon_stat</th>
#       <th id="T_f3ccd_level0_col2" class="col_heading level0 col2" >p_value</th>
#       <th id="T_f3ccd_level0_col3" class="col_heading level0 col3" >Z</th>
#       <th id="T_f3ccd_level0_col4" class="col_heading level0 col4" >Effect_size_r</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f3ccd_row0_col0" class="data row0 col0" >BASE_TEXT vs TEXT_LEMMA</td>
#       <td id="T_f3ccd_row0_col1" class="data row0 col1" >3588.000000</td>
#       <td id="T_f3ccd_row0_col2" class="data row0 col2" >0.000099</td>
#       <td id="T_f3ccd_row0_col3" class="data row0 col3" >-3.892259</td>
#       <td id="T_f3ccd_row0_col4" class="data row0 col4" >0.317802</td>
#     </tr>
#     <tr>
# ...

# %%
plt.figure(figsize=(7, 4))

sns.boxplot(
    data=df_long,
    x="Balanced",
    y="F1_macro"
)

sns.stripplot(
    data=df_long,
    x="Balanced",
    y="F1_macro",
    color="black",
    alpha=0.4,
    size=3
)

plt.title("Distribution of F1-macro across text preprocessing (TFIDF)")
plt.ylabel("F1-macro")
plt.xlabel("")
plt.tight_layout()
plt.show()
